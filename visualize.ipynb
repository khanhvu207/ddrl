# %%
import pickle
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
filepath = '/home/kvu/ddrl/benchmarks/openai-gyms/LunarLanderContinuous-v2/result-7104-2021_07_19.pickle'

# %%
res = pd.read_pickle(filepath)

# %%
scores = res['scores']
scores_window = res['scores_window']
means = res['means']

# %%
n_episodes = len(means)
fig, ax = plt.subplots()
ax.plot(np.linspace(1, n_episodes + 1, n_episodes), means)
ax.set_xlabel('Episodes')
ax.set_ylabel('Mean score of 100 consecutive episodes')
ax.set_title('LunarLanderContinuous-v2')
# Out:
# Text(0.5, 1.0, 'LunarLanderContinuous-v2')

# %%
fig.savefig('result.png')
